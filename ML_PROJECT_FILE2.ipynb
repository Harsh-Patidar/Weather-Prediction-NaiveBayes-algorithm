# %%
#NaiveBayes project(weather Prediction)
#Required Modules
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import GaussianNB

# %%
dict1={
    "Outlook":['Rainy','Rainy','Overcast','Sunny','Sunny','Sunny','Overcast','Rainy','Rainy','Sunny','Rainy','Overcast','Overcast','Sunny'],
    "Temp":['Hot','Hot','Hot','Mild','Cool','Cool','Cool','Mild','Cool','Mild','Mild','Mild','Hot','Mild'],
    "Humidity":['High','High','High','High','Normal','Normal','Normal','High','Normal','Normal','Normal','High','Normal','High'],
    "Windy":['f','t','f','f','f','t','t','f','f','f','t','t','f','t'],
    "Play":['no','no','yes','yes','yes','no','yes','no','yes','yes','yes','yes','yes','no']
}

# %%
df=pd.DataFrame(dict1)

df
# Out:
#      Outlook  Temp Humidity Windy Play
# 0      Rainy   Hot     High     f   no
# 1      Rainy   Hot     High     t   no
# 2   Overcast   Hot     High     f  yes
# 3      Sunny  Mild     High     f  yes
# 4      Sunny  Cool   Normal     f  yes
# 5      Sunny  Cool   Normal     t   no
# 6   Overcast  Cool   Normal     t  yes
# 7      Rainy  Mild     High     f   no
# 8      Rainy  Cool   Normal     f  yes
# 9      Sunny  Mild   Normal     f  yes
# 10     Rainy  Mild   Normal     t  yes
# 11  Overcast  Mild     High     t  yes
# 12  Overcast   Hot   Normal     f  yes
# 13     Sunny  Mild     High     t   no

# %%
#Converting DataFrame into csv file...
df.to_csv('New_dataset.csv')

# %%
#Reading CSV files
df=pd.read_csv('New_dataset.csv')

# %%
df
# Out:
#     Unnamed: 0   Outlook  Temp Humidity Windy Play
# 0            0     Rainy   Hot     High     f   no
# 1            1     Rainy   Hot     High     t   no
# 2            2  Overcast   Hot     High     f  yes
# 3            3     Sunny  Mild     High     f  yes
# 4            4     Sunny  Cool   Normal     f  yes
# 5            5     Sunny  Cool   Normal     t   no
# 6            6  Overcast  Cool   Normal     t  yes
# 7            7     Rainy  Mild     High     f   no
# 8            8     Rainy  Cool   Normal     f  yes
# 9            9     Sunny  Mild   Normal     f  yes
# 10          10     Rainy  Mild   Normal     t  yes
# 11          11  Overcast  Mild     High     t  yes
# 12          12  Overcast   Hot   Normal     f  yes
# 13          13     Sunny  Mild     High     t   no

# %%
#Encoding the strings to Numericals
outlook_at=LabelEncoder()
Temp_at=LabelEncoder()
Hum_at=LabelEncoder()
win_at=LabelEncoder()

# %%
#Dropping the target variable and make it is as newframe
inputs=df.drop('Play',axis='columns')
target=df['Play']
target
# Out:
# 0      no
# 1      no
# 2     yes
# 3     yes
# 4     yes
# 5      no
# 6     yes
# 7      no
# 8     yes
# 9     yes
# 10    yes
# 11    yes
# 12    yes
# 13     no
# Name: Play, dtype: object

# %%
#Creating the new dataframe
inputs['outlook_n']= outlook_at.fit_transform(inputs['Outlook'])
inputs['Temp_n']= outlook_at.fit_transform(inputs['Temp'])
inputs['Humidity_n']= outlook_at.fit_transform(inputs['Humidity'])
inputs['windy_n']= outlook_at.fit_transform(inputs['Windy'])
inputs
# Out:
#     Unnamed: 0   Outlook  Temp Humidity Windy  outlook_n  Temp_n  Humidity_n  \
# 0            0     Rainy   Hot     High     f          1       1           0
# 1            1     Rainy   Hot     High     t          1       1           0
# 2            2  Overcast   Hot     High     f          0       1           0
# 3            3     Sunny  Mild     High     f          2       2           0
# 4            4     Sunny  Cool   Normal     f          2       0           1
# 5            5     Sunny  Cool   Normal     t          2       0           1
# 6            6  Overcast  Cool   Normal     t          0       0           1
# 7            7     Rainy  Mild     High     f          1       2           0
# 8            8     Rainy  Cool   Normal     f          1       0           1
# 9            9     Sunny  Mild   Normal     f          2       2           1
# 10          10     Rainy  Mild   Normal     t          1       2           1
# 11          11  Overcast  Mild     High     t          0       2           0
# 12          12  Overcast   Hot   Normal     f          0       1           1
# 13          13     Sunny  Mild     High     t          2       2           0
#
#     windy_n
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0
# 5         1
# 6         1
# 7         0
# 8         0
# 9         0
# 10        1
# 11        1
# 12        0
# 13        1

# %%
df.to_csv('New_dataset.csv', index=False)

# %%
#Reading CSV files
df=pd.read_csv('New_dataset.csv')

# %%
df
# Out:
#     Unnamed: 0   Outlook  Temp Humidity Windy Play
# 0            0     Rainy   Hot     High     f   no
# 1            1     Rainy   Hot     High     t   no
# 2            2  Overcast   Hot     High     f  yes
# 3            3     Sunny  Mild     High     f  yes
# 4            4     Sunny  Cool   Normal     f  yes
# 5            5     Sunny  Cool   Normal     t   no
# 6            6  Overcast  Cool   Normal     t  yes
# 7            7     Rainy  Mild     High     f   no
# 8            8     Rainy  Cool   Normal     f  yes
# 9            9     Sunny  Mild   Normal     f  yes
# 10          10     Rainy  Mild   Normal     t  yes
# 11          11  Overcast  Mild     High     t  yes
# 12          12  Overcast   Hot   Normal     f  yes
# 13          13     Sunny  Mild     High     t   no

# %%
 #if you want to see the top 3 data from the upper talbe then syntax
df.head(3)
# Out:
#    Unnamed: 0   Outlook Temp Humidity Windy Play
# 0           0     Rainy  Hot     High     f   no
# 1           1     Rainy  Hot     High     t   no
# 2           2  Overcast  Hot     High     f  yes

# %%
 #if you want to see the lower 4 data from the upper talbe then syntax
df.tail(4)
# Out:
#     Unnamed: 0   Outlook  Temp Humidity Windy Play
# 10          10     Rainy  Mild   Normal     t  yes
# 11          11  Overcast  Mild     High     t  yes
# 12          12  Overcast   Hot   Normal     f  yes
# 13          13     Sunny  Mild     High     t   no

# %%
#if you want to describe the all the arithmetic operation on the numerical value in the table__
df.describe()
# Out:
#        Unnamed: 0
# count     14.0000
# mean       6.5000
# std        4.1833
# min        0.0000
# 25%        3.2500
# 50%        6.5000
# 75%        9.7500
# max       13.0000

# %%
#Dropping the string values
inputs_n=inputs.drop(['Outlook','Temp','Humidity','Windy'],axis='columns')
inputs_n
# Out:
#     Unnamed: 0  outlook_n  Temp_n  Humidity_n  windy_n
# 0            0          1       1           0        0
# 1            1          1       1           0        1
# 2            2          0       1           0        0
# 3            3          2       2           0        0
# 4            4          2       0           1        0
# 5            5          2       0           1        1
# 6            6          0       0           1        1
# 7            7          1       2           0        0
# 8            8          1       0           1        0
# 9            9          2       2           1        0
# 10          10          1       2           1        1
# 11          11          0       2           0        1
# 12          12          0       1           1        0
# 13          13          2       2           0        1

# %%
#Applying the Gaussian naivebayes
classifier = GaussianNB()
classifier.fit(inputs_n,target)
# Out:
# GaussianNB()

# %%
#85% accuracy 
classifier.score(inputs_n,target)
# Out:
# 0.7857142857142857

# %%
#Prediction
classifier.predict([[2,0,1,0,0]])
# Out:
# C:\Users\91999\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['yes'], dtype='<U3')

# %%
#Prediction
classifier.predict([[0,0,0,1]])
# Out:
# C:\Users\91999\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [21], in <cell line: 2>()
#       1 #Prediction
# ----> 2 classifier.predict([[0,0,0,1]])
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:82, in _BaseNB.predict(self, X)
#      68 """
#      69 Perform classification on an array of test vectors X.
#      70
#    (...)
#      79     Predicted target values for X.
#      80 """
#      81 check_is_fitted(self)
# ---> 82 X = self._check_X(X)
#      83 jll = self._joint_log_likelihood(X)
#      84 return self.classes_[np.argmax(jll, axis=1)]
#
# File ~\anaconda3\lib\site-packages\sklearn\naive_bayes.py:251, in GaussianNB._check_X(self, X)
#     249 def _check_X(self, X):
#     250     """Validate X, used only in predict* methods."""
# --> 251     return self._validate_data(X, reset=False)
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:585, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
# --> 585     self._check_n_features(X, reset=reset)
#     587 return out
#
# File ~\anaconda3\lib\site-packages\sklearn\base.py:400, in BaseEstimator._check_n_features(self, X, reset)
#     397     return
#     399 if n_features != self.n_features_in_:
# --> 400     raise ValueError(
#     401         f"X has {n_features} features, but {self.__class__.__name__} "
#     402         f"is expecting {self.n_features_in_} features as input."
#     403     )
#
# ValueError: X has 4 features, but GaussianNB is expecting 5 features as input.

# %%
df
# Out:
#     Unnamed: 0   Outlook  Temp Humidity Windy Play
# 0            0     Rainy   Hot     High     f   no
# 1            1     Rainy   Hot     High     t   no
# 2            2  Overcast   Hot     High     f  yes
# 3            3     Sunny  Mild     High     f  yes
# 4            4     Sunny  Cool   Normal     f  yes
# 5            5     Sunny  Cool   Normal     t   no
# 6            6  Overcast  Cool   Normal     t  yes
# 7            7     Rainy  Mild     High     f   no
# 8            8     Rainy  Cool   Normal     f  yes
# 9            9     Sunny  Mild   Normal     f  yes
# 10          10     Rainy  Mild   Normal     t  yes
# 11          11  Overcast  Mild     High     t  yes
# 12          12  Overcast   Hot   Normal     f  yes
# 13          13     Sunny  Mild     High     t   no
